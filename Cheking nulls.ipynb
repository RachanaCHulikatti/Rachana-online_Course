# %%
from pandas import read_csv
import pandas as pd
from matplotlib import pyplot

import matplotlib.pyplot as plt
# %matplotlib inline
# Load dataset
data = pd.read_csv("/home/ise_a/Downloads/II-PUC-PCB NEETCET (30042020)-grades.csv")

# %%
data
# Out:
#              Surname                            First name  \
# 0              ALVAS                       KESHAVAMURTHY S
# 1              ALVAS                          NAMRATHA K P
# 2              ALVAS                          KEERTHIRAJ S
# 3              ALVAS                  VAISHNAVI BELGAONKAR
# 4              ALVAS                          MAHESH PATIL
# 5              ALVAS                        SATHYADEEP RAO
# 6              ALVAS                        TEJASHWINI S U
# 7              ALVAS                               GURURAJ
# 8              ALVAS                      VARUN S BHANDARY
# 9              ALVAS      AVANTIKA PADMARAJ HOMBANNAVAR(A)
# 10             ALVAS                                  AMAR
# 11             ALVAS                    PRAKHYATH P SALIAN
# 12             ALVAS              PRATIBHA BABUGOUDA PATIL
# 13             ALVAS                            PAVANA K P
# 14             ALVAS                         SNEHA C AGADI
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 799 entries, 0 to 798
# Columns: 188 entries, Surname to Q. 180 /4.00
# dtypes: object(188)
# memory usage: 586.8+ KB

# %%
data.columns
# Out:
# Index(['Surname', 'First name', 'Email address', 'State', 'Started on',
#        'Completed', 'Time taken', 'Grade/720.00', 'Q. 1 /4.00', 'Q. 2 /4.00',
#        ...
#        'Q. 171 /4.00', 'Q. 172 /4.00', 'Q. 173 /4.00', 'Q. 174 /4.00',
#        'Q. 175 /4.00', 'Q. 176 /4.00', 'Q. 177 /4.00', 'Q. 178 /4.00',
#        'Q. 179 /4.00', 'Q. 180 /4.00'],
#       dtype='object', length=188)

# %%
data.shape
# Out:
# (799, 188)

# %%
data.shape
# Out:
# (799, 188)

# %%
import math
import numpy as np
import pandas as pd

data = pd.read_csv('/home/ise_a/Downloads/II-PUC-PCB NEETCET (30042020)-grades.csv')
print("The maximum marks is>>",max(data['Q. 56 /4.00']))
print("The minimum marks is>>",min(data['Q. 56 /4.00']))
# Out:
# The maximum marks is>> 4.00
# The minimum marks is>> -

# %%
data.isnull().sum() == 0
print (data)
# Out:
#              Surname                            First name  \
# 0              ALVAS                       KESHAVAMURTHY S
# 1              ALVAS                          NAMRATHA K P
# 2              ALVAS                          KEERTHIRAJ S
# 3              ALVAS                  VAISHNAVI BELGAONKAR
# 4              ALVAS                          MAHESH PATIL
# 5              ALVAS                        SATHYADEEP RAO
# 6              ALVAS                        TEJASHWINI S U
# 7              ALVAS                               GURURAJ
# 8              ALVAS                      VARUN S BHANDARY
# 9              ALVAS      AVANTIKA PADMARAJ HOMBANNAVAR(A)
# 10             ALVAS                                  AMAR
# 11             ALVAS                    PRAKHYATH P SALIAN
# 12             ALVAS              PRATIBHA BABUGOUDA PATIL
# 13             ALVAS                            PAVANA K P
# 14             ALVAS                         SNEHA C AGADI
# ...

# %%
print(data['Q. 56 /4.00'].fillna('B96 B98',inplace=True))
a = data['Q. 56 /4.00'].value_counts()
print("the no of not attempts of the question >>",a)
if 'a' == -444:
    print("The nor of not attempts ")
else:
    print("not exists")
# Out:
# None
# the no of not attempts of the question >> -        444
# -1.00    234
# 4.00     120
# 0.38       1
# Name: Q. 56 /4.00, dtype: int64
# not exists

# %%
data['Q. 56 /4.00'].value_counts().plot(kind = 'hist',title = 'GRADE ANALYSIs ', alpha= 0.80,grid = True)

plt.show()
